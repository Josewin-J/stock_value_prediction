# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_excel(r'C:\Users\Josewin\Test_dataset.xlsx','Put-Call_TS')

# %%
data.head(5)
# Out:
#   Stock Index       Put-Call Ratio           Unnamed: 2           Unnamed: 3  \
# 0         NaN  2020-08-10 00:00:00  2020-08-11 00:00:00  2020-08-12 00:00:00
# 1      AC3235                  0.8                 0.66               0.7724
# 2      AC3236                 0.86                0.732              0.85448
# 3      AC3237                 0.93                0.816              0.95024
# 4      AC3238                 1.09                1.008              1.16912
#
#             Unnamed: 4           Unnamed: 5           Unnamed: 6
# 0  2020-08-13 00:00:00  2020-08-14 00:00:00  2020-08-15 00:00:00
# 1             0.983224             0.901211             0.898368
# 2              1.08664              1.01704              1.02926
# 3               1.2073                  NaN              1.18196
# 4              1.48309              1.46106                1.531

# %%
data.drop([0],axis=0)
# Out:
#      Stock Index Put-Call Ratio Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 1         AC3235            0.8       0.66     0.7724   0.983224   0.901211
# 2         AC3236           0.86      0.732    0.85448    1.08664    1.01704
# 3         AC3237           0.93      0.816    0.95024     1.2073        NaN
# 4         AC3238           1.09      1.008    1.16912    1.48309    1.46106
# 5         AC3239            NaN      1.104    1.27856    1.62099     1.6155
# 6         AC3240            NaN      1.152    1.33328    1.68993    1.69272
# 7         AC3241           1.23      1.176    1.36064    1.72441    1.73134
# 8         AC3242              1        0.9      1.046    1.32796    1.28732
# 9         AC3243              1        0.9      1.046    1.32796    1.28732
# 10        AC3244           1.07      0.984        NaN    1.44862        NaN
# 11        AC3245           1.03      0.936    1.08704    1.37967    1.34523
# ...

# %%
data=data.rename(columns={"Put-Call Ratio":"Put-Call Ratio Day1","Unnamed: 2":"Put-Call Ratio Day2","Unnamed: 3":"Put-Call Ratio Day3","Unnamed: 4":"Put-Call Ratio Day4","Unnamed: 5":"Put-Call Ratio Day5","Unnamed: 6":"Put-Call Ratio Day6",})

# %%
data.dropna(inplace=True)

# %%
data.head(5)
# Out:
#   Stock Index Put-Call Ratio Day1 Put-Call Ratio Day2 Put-Call Ratio Day3  \
# 1      AC3235                 0.8                0.66              0.7724
# 2      AC3236                0.86               0.732             0.85448
# 4      AC3238                1.09               1.008             1.16912
# 7      AC3241                1.23               1.176             1.36064
# 8      AC3242                   1                 0.9               1.046
#
#   Put-Call Ratio Day4 Put-Call Ratio Day5 Put-Call Ratio Day6
# 1            0.983224            0.901211            0.898368
# 2             1.08664             1.01704             1.02926
# 4             1.48309             1.46106               1.531
# 7             1.72441             1.73134             1.83641
# 8             1.32796             1.28732             1.33467

# %%
n=data.shape[0]
p=data.shape[1]
n,p
# Out:
# (2715, 7)

# %%
X=data.iloc[:,1:6].values.astype(float)
Y=data.iloc[:,6:7].values.astype(float)

# %%
from sklearn.svm import SVR

# %%
regressor=SVR(kernel='rbf')
regressor.fit(X,Y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False)

# %%
test_data=pd.read_excel(r'C:\Users\Josewin\Test_dataset.xlsx','Put-Call_TS')

# %%
test_data.drop([0],axis=0)
# Out:
#      Stock Index Put-Call Ratio Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 1         AC3235            0.8       0.66     0.7724   0.983224   0.901211
# 2         AC3236           0.86      0.732    0.85448    1.08664    1.01704
# 3         AC3237           0.93      0.816    0.95024     1.2073        NaN
# 4         AC3238           1.09      1.008    1.16912    1.48309    1.46106
# 5         AC3239            NaN      1.104    1.27856    1.62099     1.6155
# 6         AC3240            NaN      1.152    1.33328    1.68993    1.69272
# 7         AC3241           1.23      1.176    1.36064    1.72441    1.73134
# 8         AC3242              1        0.9      1.046    1.32796    1.28732
# 9         AC3243              1        0.9      1.046    1.32796    1.28732
# 10        AC3244           1.07      0.984        NaN    1.44862        NaN
# 11        AC3245           1.03      0.936    1.08704    1.37967    1.34523
# ...

# %%
test_data.dropna(inplace=True)

# %%
test_data=test_data.drop(['Put-Call Ratio'],axis=1)

# %%
test_data=test_data.rename(columns={"Unnamed: 2":"Put-Call Ratio Day1","Unnamed: 3":"Put-Call Ratio Day2","Unnamed: 4":"Put-Call Ratio Day3","Unnamed: 5":"Put-Call Ratio Day4","Unnamed: 6":"Put-Call Ratio Day5",})

# %%
test_data.head(5)
# Out:
#   Stock Index Put-Call Ratio Day1 Put-Call Ratio Day2 Put-Call Ratio Day3  \
# 1      AC3235                0.66              0.7724            0.983224
# 2      AC3236               0.732             0.85448             1.08664
# 4      AC3238               1.008             1.16912             1.48309
# 7      AC3241               1.176             1.36064             1.72441
# 8      AC3242                 0.9               1.046             1.32796
#
#   Put-Call Ratio Day4 Put-Call Ratio Day5
# 1            0.901211            0.898368
# 2             1.01704             1.02926
# 4             1.46106               1.531
# 7             1.73134             1.83641
# 8             1.28732             1.33467

# %%
Z=test_data.iloc[:,1:6].values.astype(float)

# %%
Z_pred=regressor.predict(Z)

# %%
Z_pred
# Out:
# array([0.91783435, 1.06980189, 1.64833272, ..., 0.64852242, 0.89377256,
#        0.78086771])

# %%
S=test_data.iloc[:,0:1].values

# %%
a=open("Put-Call Ratio Prediction for August 16 Output.xlsx","w")
len(S)==len(Z_pred)
# Out:
# True

# %%
for i in range(0,len(Z_pred)):
    a.write("Stock Index: "+str(S[i])+"   Pull-Cut Value: "+str(Z_pred[i])+"\n")
